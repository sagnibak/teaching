# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [8, 6]
mpl.rcParams["font.size"] = 14


MIN_FLIPS = 10
MAX_FLIPS = 10000
STEP_SIZE = 5

def flip_coin(x, bias=0.5):
    """Flip a coin with bias `bias`, `x` times and return the results."""
    return np.random.randint(0, 2, (x,))

def roll_die(x):
    """Roll a fair die `x` times and return the average rolled value"""
    return np.mean(np.random.randint(1, 7, (x,)))

num_reps = list(range(MIN_FLIPS, MAX_FLIPS + 1, STEP_SIZE))

# %%
NUM_COINS = 20
BIAS = 0.7

Xs = [sum(flip_coin(NUM_COINS, BIAS)) for _ in range(1000)]

# %%
plt.plot()
# Out:
# [7,
#  11,
#  7,
#  11,
#  7,
#  10,
#  9,
#  7,
#  11,
#  9,
#  9,
#  7,
#  5,
#  14,
#  15,
#  10,
#  13,
#  6,
#  11,
#  12,
#  7,
#  10,
#  8,
#  13,
#  7,
#  8,
#  9,
#  9,
#  10,
#  8,
#  10,
#  7,
#  9,
#  11,
#  6,
#  12,
#  11,
#  7,
#  9,
#  11,
#  15,
#  11,
#  12,
#  11,
#  13,
#  5,
#  11,
#  7,
#  10,
#  11,
#  12,
#  10,
#  7,
#  13,
#  9,
#  10,
#  11,
#  10,
#  10,
#  9,
#  5,
#  11,
#  11,
#  12,
#  15,
#  10,
#  11,
#  6,
#  9,
#  7,
#  9,
#  10,
#  12,
#  12,
#  10,
#  11,
#  9,
#  13,
#  11,
#  9,
#  6,
#  12,
#  9,
#  12,
#  9,
#  11,
#  14,
#  14,
#  15,
#  9,
#  12,
#  10,
#  12,
#  11,
#  11,
#  10,
#  12,
#  12,
#  8,
#  10,
#  7,
#  12,
#  7,
#  8,
#  11,
#  11,
#  8,
#  12,
#  7,
#  10,
#  15,
#  10,
#  8,
#  11,
#  14,
#  9,
#  11,
#  10,
#  13,
#  13,
#  12,
#  12,
#  10,
#  9,
#  12,
#  10,
#  6,
#  15,
#  9,
#  7,
#  6,
#  12,
#  10,
#  10,
#  11,
#  10,
#  9,
#  13,
#  8,
#  13,
#  11,
#  13,
#  7,
#  11,
#  10,
#  10,
#  11,
#  8,
#  10,
#  12,
# ...
